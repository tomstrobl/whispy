# %% [markdown]
# # Building block — Questionnaire — configured by one file
#
# > **Building block.** A minimal, copy-pasteable block (config explanation +
# > run + save) and nothing else. Paste it together with other blocks — e.g.
# > `building_block_consent.ipynb` to get a `participant_id` — to assemble your
# > own experiment notebook.
#
#
# This notebook runs a **questionnaire** and saves the answers. Like the other
# whispy UIs it is **config-driven**: you describe the questions in
# [`configs/questionnaires/questionnaire_general.yml`](../configs/questionnaires/questionnaire_general.yml)
# and the shared look comes from [`configs/design.yml`](../configs/design.yml).
# You should not need to change any Python below — just edit the YAML.
#
# That config file has two parts:
#
# | block in the YAML | configures |
# |---|---|
# | `ui:` | layout & sizing (window size, fonts, response-box widths, spacing). Colors are inherited from `design.yml`. |
# | `questionnaire:` | the content — a list of **sections**, each holding a list of **questions**. |
#
# **Supported question types:** `text` (one line), `text_box` (multi-line),
# `numeric` (numbers only), `single_choice` (radio buttons, with an optional
# free-text "other" field) and `multiple_choice` (checkboxes).
#
# A question can also be shown conditionally with a `depends_on` block, so it only
# appears once a controlling question has a matching answer.
#
# If you haven't installed the project yet, run this from the repo root:
# `pip install -e .`

# %%
import whispy
from pathlib import Path
from whispy.ui import Questionnaire
from whispy.utils import read_config

config_path = Path('..') / 'configs' / 'questionnaires' / 'questionnaire_consent.yml'   # <- the file you edit
cfg = read_config(config_path)
print('sections:', [s['section'] for s in cfg['questionnaire']])
# Out:
# sections: ['pid', 'name', 'consent', 'listening_test_subject_hours']

# %% [markdown]
# ## See your questionnaire at a glance
#
# Open [`configs/questionnaires/questionnaire_general.yml`](../configs/questionnaires/questionnaire_general.yml)
# to edit every question (it has inline comments). The cell below prints the
# current structure — each section, then its questions with their `type`, whether
# they are `required`, and any choice `options` — so you can review the whole
# survey without leaving the notebook.

# %%
for s_i, section in enumerate(cfg['questionnaire'], start=1):
    print(f"{s_i}. {section['section']}  —  {section.get('prompt', '')}")
    for q_i, q in enumerate(section.get('questions', []), start=1):
        flag = 'required' if q.get('required') else 'optional'
        line = f"   {s_i}.{q_i} [{q['type']}, {flag}]  {q['question']}: {q.get('prompt', '')}"
        if q.get('options'):
            line += f"   options={q['options']}"
        if q.get('other_question'):
            line += "   (+ free-text 'other')"
        print(line)
# Out:
# 1. pid  —  Generate your ID for anonymously storing your data
#    1.1 [text, required]  pid_1: Enter the first letter of your mother's name (e.g. **H** for **H**anna)
#
#    1.2 [text, required]  pid_2: Enter the first letter of your father's name (e.g. **P** for **P**aul)
#
#    1.3 [text, required]  pid_3: Enter the last letter of your name (e.g. **o** for Le**o**)
#
#    1.4 [text, required]  pid_4: Enter the second digit of your birthday (e.g. **1** for 3**1**.04.2002)
#
# 2. name  —  Your name
#    2.1 [text, required]  full_name: Enter your full name
# 3. consent  —  Consent to data publication
#    3.1 [single_choice, required]  id_1: I agree that my anonymous ratings can be published and my demographic
# data can be used to compute and publish descriptive statistics (e.g., the average
# age across participants).
#    options=['Yes (continue with the listening experiment)', 'No (abort the listening experiment)']
#    3.2 [single_choice, required]  withdrawal: I understand that I can withdraw my consent at any point before the initial
# publication of the data using my name given above.
#    options=['Yes', 'No']
# 4. listening_test_subject_hours  —  Test subject hours
#    4.1 [single_choice, required]  matriculation_number: Are you studying in the Audio Communication and Technology degree program
# and would like to have your participation credited as test subject hours?
#    options=['yes', 'no']   (+ free-text 'other')

# %% [markdown]
# ## How each question type behaves
#
# - **`text`** — a single-line text box; answered when non-empty.
# - **`text_box`** — a multi-line box (height set by `ui.text_box_number_of_lines`).
# - **`numeric`** — a box that only accepts numbers; the answer comes back as a float.
# - **`single_choice`** — radio buttons (pick one). Add an `other_question` block to reveal a free-text field when a specific option is selected (see `favorite_animal` in the example config).
# - **`multiple_choice`** — checkboxes (pick any number); the answer is a list.
#
# Mark a question `required: true` to force an answer. When the participant clicks
# **Continue**, any unanswered required questions are listed in a popup and the
# window stays open until they are filled in. Set `ui.enumerate: true` to number
# the sections and questions automatically.

# %% [markdown]
# ## Run the questionnaire
#
# The cell below opens the questionnaire window and **blocks** until the
# participant finishes and clicks **Continue**. As with the other whispy UIs,
# `Continue` only releases control once every required question is answered; the
# window then stays open until we explicitly `close()` it.
#
# > Tip: while developing, pass `debug=True` to `Questionnaire(...)` to enable the
# > native close button and skip the required-answer check.

# %%
questionnaire = Questionnaire(questionnaire=config_path, blocking=True)
results = questionnaire.get_results()
questionnaire.close()
results
# Out:
#                         section              question  \
# 0                           pid                 pid_1
# 1                           pid                 pid_2
# 2                           pid                 pid_3
# 3                           pid                 pid_4
# 4                          name             full_name
# 5                       consent                  id_1
# 6                       consent            withdrawal
# 7  listening_test_subject_hours  matriculation_number
#
#                                               prompt           type  required  \
# 0  1.1 Enter the first letter of your mother's na...           text      True
# 1  1.2 Enter the first letter of your father's na...           text      True
# 2  1.3 Enter the last letter of your name (e.g. *...           text      True
# 3  1.4 Enter the second digit of your birthday (e...           text      True
# 4                           2.1 Enter your full name           text      True
# 5  3.1 I agree that my anonymous ratings can be p...  single_choice      True
# 6  3.2 I understand that I can withdraw my consen...  single_choice      True
# 7  4.1 Are you studying in the Audio Communicatio...  single_choice      True
#
#                                          answer
# 0                                             e
# 1                                             e
# 2                                             o
# 3                                             1
# 4                                         ersf,
# 5  Yes (continue with the listening experiment)
# 6                                           Yes
# 7                                       12345.0

# %% [markdown]
# ## The results
#
# `get_results()` returns a `pandas.DataFrame` with **one row per question** and
# the columns `section, question, prompt, type, required, answer`. For
# `multiple_choice` the `answer` is a list of the selected options; for a
# `single_choice` with an "other" field it is the typed text when that option was
# chosen.

# %%
print('answered rows:', len(results))
results
# Out:
# answered rows: 8
#                         section              question  \
# 0                           pid                 pid_1
# 1                           pid                 pid_2
# 2                           pid                 pid_3
# 3                           pid                 pid_4
# 4                          name             full_name
# 5                       consent                  id_1
# 6                       consent            withdrawal
# 7  listening_test_subject_hours  matriculation_number
#
#                                               prompt           type  required  \
# 0  1.1 Enter the first letter of your mother's na...           text      True
# 1  1.2 Enter the first letter of your father's na...           text      True
# 2  1.3 Enter the last letter of your name (e.g. *...           text      True
# 3  1.4 Enter the second digit of your birthday (e...           text      True
# 4                           2.1 Enter your full name           text      True
# 5  3.1 I agree that my anonymous ratings can be p...  single_choice      True
# 6  3.2 I understand that I can withdraw my consen...  single_choice      True
# 7  4.1 Are you studying in the Audio Communicatio...  single_choice      True
#
#                                          answer
# 0                                             e
# 1                                             e
# 2                                             o
# 3                                             1
# 4                                         ersf,
# 5  Yes (continue with the listening experiment)
# 6                                           Yes
# 7                                       12345.0

# %% [markdown]
# ## Save the results
#
# Save the answers to a CSV in a `results/` folder (created next to this notebook).
# If this is the consent questionnaire (it has `pid_1..pid_4`), an anonymous
# participant id is built from those answers and used in the file name
# (`<config>_<id>_<timestamp>.csv`). Keep the `participant_id` variable in scope and
# pass it to the `save_results(...)` calls of any test blocks you add below, so all
# of a participant's files share the id. Without an id an iterating number is used
# (`<config>_<NNN>_<timestamp>.csv`). Existing files are never overwritten.

# %%
from whispy.utils import save_results, participant_id_from_consent

# Build an anonymous participant id from the consent answers (pid_1..pid_4).
# Keep this `participant_id` in scope: when you assemble a full experiment by
# pasting other test blocks below, pass it to their save_results(...) calls so
# every file is named for the same participant.
participant_id = participant_id_from_consent(results)
if participant_id:
    print('participant id:', participant_id)

results_path = save_results(results, config_path.stem, participant_id=participant_id)
print('saved results to', results_path.resolve())
# Out:
# participant id: eeo1
# saved results to /Users/tomstrobl/Documents/GitHub/whispy/examples/results/questionnaire_consent_eeo1_20260625_215047.csv

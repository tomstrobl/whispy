# %%
from whispy.utils import Plotting
from pathlib import Path

plt = Plotting()

# %%
path = Path('..') / 'examples' / 'results'

staircase_csv = path / 'staircase_n_afc_abc1_20260712_134500.csv'
staircase_df = plt.read_results(staircase_csv)

mushra_csv = path / 'drag_and_drop_mushra_abc1_20260712_121836.csv'
mushra_df = plt.read_results(mushra_csv)

abx_csv = path / 'abx_abc1_20260712_134750.csv'
abx_df = plt.read_results(abx_csv)

plt.plot_staircase(staircase_df, caption_bool=True)
plt.plot_staircase_rt_boxplot(staircase_df, caption_bool=True)
plt.plot_staircase_correctness_rt_over_trials(staircase_df, caption_bool=True)

plt.plot_mushra_rt_boxplot(mushra_df, caption_bool=True)
plt.plot_mushra_rt_over_trials(mushra_df, caption_bool=True)
plt.plot_mushra_mean_ratings(mushra_df, caption_bool=True)
plt.plot_mushra_summary_distribution(mushra_df)

plt.plot_abx_accuracy_by_section(abx_df, caption_bool=True)
plt.plot_abx_rt_boxplot(abx_df, caption_bool=True)
plt.plot_abx_correctness_rt_over_trials(abx_df, caption_bool=True)
